# %% [markdown]
# ## Introduction.
# Hamburg is the second-largest city in Germany and is known to be the greenest city in the Country, rich in recreational areas.\
# Moving inside Hamburg to an area closer to my work, I was looking for a place to live in a neighborhood where I could also easily walk my dog and play basketball in the evenings. Searching for a new dwelling I realized that boroughs of the city distinguishes from each other in this aspect.\
# In this project I would like to explore neighborhoods in Hamburg for availability of sports grounds and green areas. Such clustering and its visualisation can provide with an information about parts of the city with a lack of places to rest. This information can be used by management of the city to make Hamburg even more better place to live. Moreover, this report is useful for someone who is looking for a place in Hamburg for recreational purposes.

# %% [markdown]
# ## Description of the data to be used in the analysis.
# The data for the analysis will be combined from two data sets. The first one contains geographical coordinates for every postal code in Hamburg. The second one provides us with information about boroughs and neighborhoods corresponding to each postal code.\
# Resulting data set will contain boroughs and neighborhoods, postal codes and related longitude and latitude. It will be used to explore the neighborhoods and segment them with the Foursquare API. With the k-means clustering algorithm we will cluster the neighbourhoods in Hamburg and visualise them for observations and analysis.

# %% [markdown]
# Before to get the data and start exploring it, several libraries should be installed.

# %%
import requests # library to handle requests

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files


from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Datasets

# %% [markdown]
# The first dataset contains the data of all german postal codes, cities and their coordinataes

# %%
url='https://launix.de/launix/wp-content/uploads/2019/06/PLZ.csv'

# %%
headers = ["PostalCode","City","Longitude","Latitude"]

# %% [markdown]
# Transform the data into a pandas dataframe and choose the only positions related to Hamburg

# %%
df = pd.read_csv(url, skiprows=3, names = headers, sep=';')

# %%
df_h=df[df['City']=='Hamburg'].reset_index(drop=True)

df_h.head()
# Out:
#    PostalCode     City  Longitude   Latitude
# 0       20095  Hamburg  10.001104  53.554158
# 1       20097  Hamburg  10.020163  53.549704
# 2       20099  Hamburg  10.011777  53.560801
# 3       20144  Hamburg   9.975633  53.577054
# 4       20146  Hamburg   9.978171  53.570563

# %% [markdown]
# Dowmload and explore the second dataset with Postal Codes, Boroughs and Neighbourhoods of Hamburg.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#the datasets columns need to be renamed because of german transcription
column_names= ['1','2','3','4','5','6','7','8','Neighborhood', 'Borough',"PostalCode",'12']
url1='https://www.statistik-nord.de/fileadmin/Dokumente/Wahlen/Hamburg/Bezirksversammlungswahlen/2019/Vor_der_Wahl/2018-06-19Stra%C3%9FenHH_WahlkreisBVWahl_Stadtteil_PLZ.xlsx'

# %%
df_plz = pd.read_excel(url1,names = column_names)

# %%
#drop the first row because it's empty
df_plz = df_plz.iloc[1:]

# %%
df_plz.head(3)
# Out:
#                  1  2    3   4    5  6   7  \
# 1  Aalheitengraben  1  NaN   3  NaN  1  57
# 2  Aalheitengraben  4  NaN  14  NaN  2  57
# 3      Aalkrautweg  1  NaN  35    a  1  55
#
#                                                    8 Neighborhood   Borough  \
# 1  Lemsahl-Mellingstedt, Duvenstedt, Wohldorf-Ohl...    Volksdorf  Wandsbek
# 2  Lemsahl-Mellingstedt, Duvenstedt, Wohldorf-Ohl...    Volksdorf  Wandsbek
# 3                              Wellingsbüttel, Sasel        Sasel  Wandsbek
#
#   PostalCode    12
# 1      22359  A001
# 2      22359  A001
# 3      22395  A002

# %%
#Let's drop all usless for the analysis columns 
df_test=df_plz.drop(['1','2','3','4','5','6','7','8','12'], axis=1)
df_test.head()
# Out:
#   Neighborhood   Borough PostalCode
# 1    Volksdorf  Wandsbek      22359
# 2    Volksdorf  Wandsbek      22359
# 3        Sasel  Wandsbek      22395
# 4        Sasel  Wandsbek      22395
# 5        Sasel  Wandsbek      22393

# %% [markdown]
# at this step we will merge both datasets on postal codes

# %%
df_hamburg = pd.merge(df_h, df_test, on='PostalCode',how='inner')
df_hamburg.head()
# Out:
#   PostalCode     City  Longitude   Latitude      Neighborhood        Borough
# 0      20095  Hamburg  10.001104  53.554158  Hamburg-Altstadt  Hamburg-Mitte
# 1      20095  Hamburg  10.001104  53.554158  Hamburg-Altstadt  Hamburg-Mitte
# 2      20095  Hamburg  10.001104  53.554158       Hammerbrook  Hamburg-Mitte
# 3      20095  Hamburg  10.001104  53.554158  Hamburg-Altstadt  Hamburg-Mitte
# 4      20095  Hamburg  10.001104  53.554158  Hamburg-Altstadt  Hamburg-Mitte

# %%
# let's check the shape
df_hamburg.shape
# Out:
# (15491, 6)

# %%
#drop duplicates
df_hamburg.sort_values("Neighborhood", inplace = True)
df_hamburg.drop_duplicates(subset="Neighborhood", keep='first', inplace=True)

# %%
df_hamburg.reset_index(drop=True)
# Out:
#     PostalCode     City  Longitude   Latitude          Neighborhood  \
# 0        21037  Hamburg  10.144101  53.450581             Allermöhe
# 1        22297  Hamburg  10.012196  53.611496            Alsterdorf
# 2        21039  Hamburg  10.261889  53.455322            Altengamme
# 3        21129  Hamburg   9.848822  53.524423           Altenwerder
# 4        22767  Hamburg   9.947594  53.553175       Altona-Altstadt
# 5        22765  Hamburg   9.932502  53.557255           Altona-Nord
# 6        22607  Hamburg   9.879987  53.571865            Bahrenfeld
# 7        22305  Hamburg  10.049692  53.591714          Barmbek-Nord
# 8        22085  Hamburg  10.015176  53.574655           Barmbek-Süd
# 9        21035  Hamburg  10.150629  53.494515             Bergedorf
# 10       22395  Hamburg  10.114463  53.674986             Bergstedt
# 11       20539  Hamburg  10.046461  53.528866             Billbrook
# 12       22119  Hamburg  10.105736  53.559444             Billstedt
# 13       21033  Hamburg  10.162769  53.508193            Billwerder
# 14       22587  Hamburg   9.799340  53.565260            Blankenese
# 15       20535  Hamburg  10.049668  53.562062             Borgfelde
# 16       22175  Hamburg  10.098383  53.629114              Bramfeld
# 17       21129  Hamburg   9.848822  53.524423                 Cranz
# 18       21039  Hamburg  10.261889  53.455322              Curslack
# 19       22049  Hamburg  10.067150  53.588977              Dulsberg
# 20       22397  Hamburg  10.124170  53.706996            Duvenstedt
# 21       22523  Hamburg   9.898102  53.616042            Eidelstedt
# 22       22089  Hamburg  10.047103  53.570657                Eilbek
# 23       20257  Hamburg   9.942673  53.579107            Eimsbüttel
# 24       21073  Hamburg   9.971671  53.460295             Eißendorf
# 25       22529  Hamburg   9.955756  53.598736             Eppendorf
# 26       22159  Hamburg  10.117659  53.616347         Farmsen-Berne
# 27       21129  Hamburg   9.848822  53.524423          Finkenwerder
# 28       21129  Hamburg   9.848822  53.524423               Francop
# 29       22335  Hamburg   9.997822  53.631971           Fuhlsbüttel
# 30       22335  Hamburg   9.997822  53.631971          Groß Borstel
# 31       22607  Hamburg   9.879987  53.571865         Groß Flottbek
# 32       21079  Hamburg   9.975740  53.468739              Gut Moor
# 33       20457  Hamburg   9.978617  53.535713             HafenCity
# 34       20095  Hamburg  10.001104  53.554158      Hamburg-Altstadt
# 35       20535  Hamburg  10.049668  53.562062                  Hamm
# 36       20097  Hamburg  10.020163  53.549704           Hammerbrook
# 37       21073  Hamburg   9.971671  53.460295               Harburg
# 38       20149  Hamburg   9.992131  53.581092          Harvestehude
# 39       21147  Hamburg   9.851611  53.486554             Hausbruch
# 40       21079  Hamburg   9.975740  53.468739              Heimfeld
# 41       20251  Hamburg   9.977862  53.595006          Hoheluft-Ost
# 42       20253  Hamburg   9.966791  53.582910         Hoheluft-West
# 43       22087  Hamburg  10.024729  53.565123            Hohenfelde
# 44       22111  Hamburg  10.082665  53.550699                  Horn
# 45       22399  Hamburg  10.070814  53.667414         Hummelsbüttel
# 46       22589  Hamburg   9.807149  53.585539             Iserbrook
# 47       22043  Hamburg  10.103472  53.572270               Jenfeld
# 48       21037  Hamburg  10.144101  53.450581           Kirchwerder
# 49       20457  Hamburg   9.978617  53.535713     Kleiner Grasbrook
# 50       21079  Hamburg   9.975740  53.468739             Langenbek
# 51       22417  Hamburg  10.034496  53.670652            Langenhorn
# 52       22397  Hamburg  10.124170  53.706996  Lemsahl-Mellingstedt
# 53       21033  Hamburg  10.162769  53.508193             Lohbrügge
# 54       22529  Hamburg   9.955756  53.598736              Lokstedt
# 55       22547  Hamburg   9.878452  53.601647                 Lurup
# 56       22043  Hamburg  10.103472  53.572270            Marienthal
# 57       21077  Hamburg   9.949723  53.439033             Marmstorf
# 58       21079  Hamburg   9.975740  53.468739              Moorburg
# 59       21035  Hamburg  10.150629  53.494515          Neuallermöhe
# 60       21129  Hamburg   9.848822  53.524423            Neuenfelde
# 61       21039  Hamburg  10.261889  53.455322            Neuengamme
# 62       21149  Hamburg   9.857171  53.463487    Neugraben-Fischbek
# 63       21079  Hamburg   9.975740  53.468739               Neuland
# 64       20355  Hamburg   9.978956  53.558257              Neustadt
# 65       27499  Hamburg   8.467722  53.940192               Neuwerk
# 66       22459  Hamburg   9.934656  53.628036              Niendorf
# 67       22609  Hamburg   9.850548  53.561456           Nienstedten
# 68       21037  Hamburg  10.144101  53.450581          Ochsenwerder
# 69       22297  Hamburg  10.012196  53.611496              Ohlsdorf
# 70       22549  Hamburg   9.854926  53.587857                Osdorf
# 71       22605  Hamburg   9.887015  53.552819           Othmarschen
# 72       22765  Hamburg   9.932502  53.557255              Ottensen
# 73       22399  Hamburg  10.070814  53.667414          Poppenbüttel
# 74       22145  Hamburg  10.209996  53.619964             Rahlstedt
# 75       21037  Hamburg  10.144101  53.450581             Reitbrook
# 76       22559  Hamburg   9.760451  53.590292                Rissen
# 77       20539  Hamburg  10.046461  53.528866        Rothenburgsort
# 78       20146  Hamburg   9.978171  53.570563            Rotherbaum
# 79       21079  Hamburg   9.975740  53.468739             Rönneburg
# 80       22393  Hamburg  10.122762  53.655542                 Sasel
# 81       22457  Hamburg   9.911204  53.641559             Schnelsen
# 82       21079  Hamburg   9.975740  53.468739              Sinstorf
# 83       21037  Hamburg  10.144101  53.450581            Spadenland
# 84       22087  Hamburg  10.024729  53.565123             St. Georg
# 85       20359  Hamburg   9.965141  53.553306             St. Pauli
# 86       22309  Hamburg  10.055356  53.614629            Steilshoop
# 87       20457  Hamburg   9.978617  53.535713           Steinwerder
# 88       22527  Hamburg   9.928548  53.602410            Stellingen
# 89       20357  Hamburg   9.966303  53.565085          Sternschanze
# 90       22589  Hamburg   9.807149  53.585539              Sülldorf
# 91       21037  Hamburg  10.144101  53.450581             Tatenberg
# 92       22047  Hamburg  10.091898  53.590942              Tonndorf
# 93       22081  Hamburg  10.043227  53.578604            Uhlenhorst
# 94       20539  Hamburg  10.046461  53.528866                Veddel
# 95       22359  Hamburg  10.164645  53.655317             Volksdorf
# 96       21129  Hamburg   9.848822  53.524423            Waltershof
# 97       22041  Hamburg  10.076306  53.578344              Wandsbek
# 98       22393  Hamburg  10.122762  53.655542        Wellingsbüttel
# 99       20457  Hamburg   9.978617  53.535713          Wilhelmsburg
# 100      21077  Hamburg   9.949723  53.439033              Wilstorf
# 101      22303  Hamburg  10.022195  53.594214            Winterhude
# 102      22397  Hamburg  10.124170  53.706996     Wohldorf-Ohlstedt
#
#            Borough
# 0        Bergedorf
# 1     Hamburg-Nord
# 2        Bergedorf
# 3          Harburg
# 4           Altona
# 5           Altona
# 6           Altona
# 7     Hamburg-Nord
# 8     Hamburg-Nord
# 9        Bergedorf
# 10        Wandsbek
# 11   Hamburg-Mitte
# 12   Hamburg-Mitte
# 13       Bergedorf
# 14          Altona
# 15   Hamburg-Mitte
# 16        Wandsbek
# 17         Harburg
# 18       Bergedorf
# 19    Hamburg-Nord
# 20        Wandsbek
# 21      Eimsbüttel
# 22        Wandsbek
# 23      Eimsbüttel
# 24         Harburg
# 25    Hamburg-Nord
# 26        Wandsbek
# 27   Hamburg-Mitte
# 28         Harburg
# 29    Hamburg-Nord
# 30    Hamburg-Nord
# 31          Altona
# 32         Harburg
# 33   Hamburg-Mitte
# 34   Hamburg-Mitte
# 35   Hamburg-Mitte
# 36   Hamburg-Mitte
# 37         Harburg
# 38      Eimsbüttel
# 39         Harburg
# 40         Harburg
# 41    Hamburg-Nord
# 42      Eimsbüttel
# 43    Hamburg-Nord
# 44   Hamburg-Mitte
# 45        Wandsbek
# 46          Altona
# 47        Wandsbek
# 48       Bergedorf
# 49   Hamburg-Mitte
# 50         Harburg
# 51    Hamburg-Nord
# 52        Wandsbek
# 53       Bergedorf
# 54      Eimsbüttel
# 55          Altona
# 56        Wandsbek
# 57         Harburg
# 58         Harburg
# 59       Bergedorf
# 60         Harburg
# 61       Bergedorf
# 62         Harburg
# 63         Harburg
# 64   Hamburg-Mitte
# 65   Hamburg-Mitte
# 66      Eimsbüttel
# 67          Altona
# 68       Bergedorf
# 69    Hamburg-Nord
# 70          Altona
# 71          Altona
# 72          Altona
# 73        Wandsbek
# 74        Wandsbek
# 75       Bergedorf
# 76          Altona
# 77   Hamburg-Mitte
# 78      Eimsbüttel
# 79         Harburg
# 80        Wandsbek
# 81      Eimsbüttel
# 82         Harburg
# 83       Bergedorf
# 84   Hamburg-Mitte
# 85   Hamburg-Mitte
# 86        Wandsbek
# 87   Hamburg-Mitte
# 88      Eimsbüttel
# 89          Altona
# 90          Altona
# 91       Bergedorf
# 92        Wandsbek
# 93    Hamburg-Nord
# 94   Hamburg-Mitte
# 95        Wandsbek
# 96   Hamburg-Mitte
# 97        Wandsbek
# 98        Wandsbek
# 99   Hamburg-Mitte
# 100        Harburg
# 101   Hamburg-Nord
# 102       Wandsbek

# %% [markdown]
# The Dataset is ready. Let's check its size

# %%
print('the number of uniq neighborhoods is')
df_hamburg.shape
# Out:
# the number of uniq neighborhoods is
# (103, 6)

# %% [markdown]
# Now we will define Foursquare Credentials and Version

# %%
CLIENT_ID = 'PRGJP2KTHQJW2GSA1O4BJC1UTQCBLQ5SPTGOAH4BN3TXAUAF' # your Foursquare ID
CLIENT_SECRET = 'A4V0FBT01TBMDP4E24R52W2K3SYQNZF023AT1ZGV0D2MCZ3X' # your Foursquare Secret

VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PRGJP2KTHQJW2GSA1O4BJC1UTQCBLQ5SPTGOAH4BN3TXAUAF
# CLIENT_SECRET:A4V0FBT01TBMDP4E24R52W2K3SYQNZF023AT1ZGV0D2MCZ3X

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.20.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium # map rendering library

# %%
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
address = 'Hamburg'

geolocator = Nominatim(user_agent="h_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Hamburg are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Hamburg are 53.550341, 10.000654.

# %% [markdown]
# let's visualize the neighborhoods in Hamburg.

# %%
# create map of Hamburg using latitude and longitude values
map_hamburg = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_hamburg['Latitude'], df_hamburg['Longitude'], df_hamburg['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_hamburg)  
    
map_hamburg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dd812b6f2bd04b48acdf70e37a63f072%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dd812b6f2bd04b48acdf70e37a63f072%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dd812b6f2bd04b48acdf70e37a63f072%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dd812b6f2bd04b48acdf70e37a63f072%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.550341%2C%2010.000654%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# let's explore the first neighborhood in our dataframe
neighborhood_latitude = df_hamburg.loc[0,'Latitude'] # neighborhood latitude value
neighborhood_longitude = df_hamburg.loc[0,'Longitude'] # neighborhood longitude value

neighborhood_name = df_hamburg.loc[0,'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Hamburg-Altstadt are 53.5541579534295, 10.0011036114924.

# %% [markdown]
# Now, let's get the top 100 venues that are within a radius of 500 meters.\
# First, let's create the GET request URL.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=PRGJP2KTHQJW2GSA1O4BJC1UTQCBLQ5SPTGOAH4BN3TXAUAF&client_secret=A4V0FBT01TBMDP4E24R52W2K3SYQNZF023AT1ZGV0D2MCZ3X&v=20180605&ll=53.5541579534295,10.0011036114924&radius=500&limit=100'

# %% [markdown]
# Extract and Explore Neighborhood by Venue

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '609aacb5d2c21539de9c6439'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Hamburg-Altstadt',
#   'headerFullLocation': 'Hamburg-Altstadt, Hamburg',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 102,
#   'suggestedBounds': {'ne': {'lat': 53.558657957929505,
#     'lng': 10.008664433891797},
#    'sw': {'lat': 53.5496579489295, 'lng': 9.993542789093004}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0d3ac1f964a520dd4423e3',
#        'name': 'Sakura Sushi',
#        'location': {'address': 'Rosenstr. 8',
#         'lat': 53.552441853233546,
#         'lng': 10.000058291854657,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.552441853233546,
#           'lng': 10.000058291854657}],
#         'distance': 203,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Rosenstr. 8', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0d3ac1f964a520dd4423e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05885ff964a5207cc122e3',
#        'name': 'Hamburger Kunsthalle - Galerie der Gegenwart',
#        'location': {'address': 'Glockengießerwall 5',
#         'crossStreet': 'Georgsplatz',
#         'lat': 53.55537595765216,
#         'lng': 10.002738939342995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55537595765216,
#           'lng': 10.002738939342995}],
#         'distance': 173,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Glockengießerwall 5 (Georgsplatz)',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05885ff964a5207cc122e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4fbf00e4b024479530b7e8',
#        'name': 'Barceló Hamburg',
#        'location': {'address': 'Ferdinandstr. 15',
#         'lat': 53.55443196349585,
#         'lng': 10.000625024504766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55443196349585,
#           'lng': 10.000625024504766}],
#         'distance': 43,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ferdinandstr. 15',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4fbf00e4b024479530b7e8-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c90c0992626a1cd22122c6b',
#        'name': 'Quan Do',
#        'location': {'address': 'Georgsplatz 16',
#         'lat': 53.553372943644646,
#         'lng': 10.00255823135376,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.553372943644646,
#           'lng': 10.00255823135376}],
#         'distance': 129,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Georgsplatz 16',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c90c0992626a1cd22122c6b-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058861f964a52041c222e3',
#        'name': 'Thalia Theater',
#        'location': {'address': 'Alstertor 1',
#         'lat': 53.552000380740026,
#         'lng': 9.998337775468826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.552000380740026,
#           'lng': 9.998337775468826}],
#         'distance': 301,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alstertor 1', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058861f964a52041c222e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '547a2e79498e385d53f9f8e4',
#        'name': 'cohibar',
#        'location': {'address': 'Gertrudenkirchhof 10',
#         'lat': 53.552515355955954,
#         'lng': 10.000686774553706,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.552515355955954,
#           'lng': 10.000686774553706}],
#         'distance': 184,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Gertrudenkirchhof 10',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d119941735',
#          'name': 'Hookah Bar',
#          'pluralName': 'Hookah Bars',
#          'shortName': 'Hookah Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/hookahbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-547a2e79498e385d53f9f8e4-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058863f964a520c9c222e3',
#        'name': 'Michelle Records',
#        'location': {'address': 'Gertrudenkirchhof 10',
#         'lat': 53.55237783887337,
#         'lng': 10.000934717740618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55237783887337,
#           'lng': 10.000934717740618}],
#         'distance': 198,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Gertrudenkirchhof 10',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d10d951735',
#          'name': 'Record Shop',
#          'pluralName': 'Record Shops',
#          'shortName': 'Record Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058863f964a520c9c222e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7f868a171b224b1ff010b1',
#        'name': 'Mitri Saliba',
#        'location': {'address': 'Gertrudenstraße',
#         'crossStreet': 'Raboisen',
#         'lat': 53.553032,
#         'lng': 10.000012,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.553032,
#           'lng': 10.000012}],
#         'distance': 144,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Gertrudenstraße (Raboisen)',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7f868a171b224b1ff010b1-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2f724bf964a52076eb24e3',
#        'name': 'Tschebull',
#        'location': {'address': 'Mönckebergstr. 7',
#         'lat': 53.551418528651986,
#         'lng': 10.003051968035546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.551418528651986,
#           'lng': 10.003051968035546}],
#         'distance': 331,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mönckebergstr. 7',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a01',
#          'name': 'Austrian Restaurant',
#          'pluralName': 'Austrian Restaurants',
#          'shortName': 'Austrian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/austrian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '54162147'}},
#       'referralId': 'e-0-4b2f724bf964a52076eb24e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8060f9551ea1cd916719c5',
#        'name': 'Nachtasyl',
#        'location': {'address': 'Alstertor 1',
#         'lat': 53.5519716980625,
#         'lng': 9.998252615332603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.5519716980625,
#           'lng': 9.998252615332603}],
#         'distance': 307,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alstertor 1', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8060f9551ea1cd916719c5-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '504dde86e4b00e670d9713bc',
#        'name': 'Alsterfontäne',
#        'location': {'address': 'Ballindamm',
#         'lat': 53.55509640211534,
#         'lng': 9.996142387390137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55509640211534,
#           'lng': 9.996142387390137}],
#         'distance': 344,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ballindamm', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '56aa371be4b08b9a8d573547',
#          'name': 'Fountain',
#          'pluralName': 'Fountains',
#          'shortName': 'Fountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-504dde86e4b00e670d9713bc-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52235d6411d2672014302c53',
#        'name': 'P&B Press and Books',
#        'location': {'address': 'Glockengießerwall 8-10',
#         'lat': 53.55327164097696,
#         'lng': 10.00585007126826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55327164097696,
#           'lng': 10.00585007126826}],
#         'distance': 329,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Glockengießerwall 8-10',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52235d6411d2672014302c53-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54143343498e36876807d804',
#        'name': 'Team Breakout Games',
#        'location': {'lat': 53.55395580451885,
#         'lng': 10.001281303005959,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55395580451885,
#           'lng': 10.001281303005959}],
#         'distance': 25,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '5f2c2834b6d05514c704451e',
#          'name': 'Escape Room',
#          'pluralName': 'Escape Rooms',
#          'shortName': 'Escape Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54143343498e36876807d804-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '520de75b11d2a9d3ac79f1ee',
#        'name': 'Enjoy Coffee Bar',
#        'location': {'address': 'Rosenstrasse 17',
#         'lat': 53.5531358263793,
#         'lng': 10.00138546939593,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.5531358263793,
#           'lng': 10.00138546939593}],
#         'distance': 115,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Rosenstrasse 17',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-520de75b11d2a9d3ac79f1ee-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b484b9bf964a520474b26e3',
#        'name': 'Park Hyatt Hamburg',
#        'location': {'address': 'Bugenhagenstr. 8',
#         'lat': 53.55097660815807,
#         'lng': 10.003158360934489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55097660815807,
#           'lng': 10.003158360934489}],
#         'distance': 379,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Bugenhagenstr. 8',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b484b9bf964a520474b26e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1105c6f964a5208a7723e3',
#        'name': 'LEGO Store',
#        'location': {'address': 'Spitalerstr. 12',
#         'lat': 53.55208952131619,
#         'lng': 10.002382649061493,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55208952131619,
#           'lng': 10.002382649061493}],
#         'distance': 245,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Spitalerstr. 12',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1f3941735',
#          'name': 'Toy / Game Store',
#          'pluralName': 'Toy / Game Stores',
#          'shortName': 'Toys & Games',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/toys_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1105c6f964a5208a7723e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b92affff964a5208e1134e3',
#        'name': 'Binnenalster',
#        'location': {'address': 'Jungfernstieg',
#         'crossStreet': 'Ballindamm',
#         'lat': 53.555090028655016,
#         'lng': 9.995133876800537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.555090028655016,
#           'lng': 9.995133876800537}],
#         'distance': 408,
#         'postalCode': '20354',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Jungfernstieg (Ballindamm)',
#          '20354 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b92affff964a5208e1134e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf3c86e7e93f04ddc095a69',
#        'name': 'New Yorker',
#        'location': {'address': 'Mönckebergstr.',
#         'lat': 53.55236862665842,
#         'lng': 10.003593114653263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55236862665842,
#           'lng': 10.003593114653263}],
#         'distance': 258,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mönckebergstr.',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf3c86e7e93f04ddc095a69-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05885df964a520e3c022e3',
#        'name': 'Lombardsbrücke',
#        'location': {'address': 'Lombardsbrücke',
#         'crossStreet': 'Binnenalster',
#         'lat': 53.557013829427156,
#         'lng': 9.997118494182319,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.557013829427156,
#           'lng': 9.997118494182319}],
#         'distance': 412,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'neighborhood': 'Neustadt, Hamburg',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Lombardsbrücke (Binnenalster)',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1df941735',
#          'name': 'Bridge',
#          'pluralName': 'Bridges',
#          'shortName': 'Bridge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/bridge_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05885df964a520e3c022e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a5f665498e8c3c66ee9008',
#        'name': 'Comida',
#        'location': {'address': 'Spitalerstr. 22',
#         'lat': 53.55214587782874,
#         'lng': 9.999825215107663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55214587782874,
#           'lng': 9.999825215107663}],
#         'distance': 239,
#         'cc': 'DE',
#         'neighborhood': 'Hamburg-Altstadt',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Spitalerstr. 22', 'Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a5f665498e8c3c66ee9008-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b954136f964a5203f9834e3',
#        'name': 'MAC Cosmetics',
#        'location': {'address': 'Mönckebergstraße 10',
#         'lat': 53.55154325715734,
#         'lng': 10.003027190885966,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55154325715734,
#           'lng': 10.003027190885966}],
#         'distance': 317,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mönckebergstraße 10',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b954136f964a5203f9834e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d720fcd8e12b1f740633505',
#        'name': 'Lunge Laufladen',
#        'location': {'address': 'Ferdinandstraße 55',
#         'lat': 53.553219886046044,
#         'lng': 9.998744352238424,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.553219886046044,
#           'lng': 9.998744352238424}],
#         'distance': 187,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ferdinandstraße 55',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d720fcd8e12b1f740633505-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b114919f964a520bf7923e3',
#        'name': 'Depot',
#        'location': {'address': 'Spitalerstr. 10',
#         'crossStreet': 'Semperhaus A',
#         'lat': 53.55216799573467,
#         'lng': 10.003090051719806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55216799573467,
#           'lng': 10.003090051719806}],
#         'distance': 257,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Spitalerstr. 10 (Semperhaus A)',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b114919f964a520bf7923e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058857f964a5203cbf22e3',
#        'name': 'Hotel Atlantic Kempinski',
#        'location': {'address': 'An Der Alster 72-79',
#         'lat': 53.55732419988311,
#         'lng': 10.005026542773097,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55732419988311,
#           'lng': 10.005026542773097}],
#         'distance': 437,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['An Der Alster 72-79',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '77440487'}},
#       'referralId': 'e-0-4b058857f964a5203cbf22e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b14c7cef964a5207ba623e3',
#        'name': 'Mutterland Stammhaus',
#        'location': {'address': 'Ernst-Merck-Str. 9',
#         'crossStreet': 'Kirchenallee',
#         'lat': 53.55493980889312,
#         'lng': 10.007610654611444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55493980889312,
#           'lng': 10.007610654611444}],
#         'distance': 439,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'neighborhood': 'St. Georg',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ernst-Merck-Str. 9 (Kirchenallee)',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b14c7cef964a5207ba623e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058866f964a520adc322e3',
#        'name': 'Levantehaus',
#        'location': {'address': 'Mönckebergstr. 7',
#         'lat': 53.551112802211485,
#         'lng': 10.003008842468262,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.551112802211485,
#           'lng': 10.003008842468262}],
#         'distance': 361,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mönckebergstr. 7',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058866f964a520adc322e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c39bc23dfb0e21eeae0b0a8',
#        'name': 'Passage Kino',
#        'location': {'address': 'Mönckebergstr. 17',
#         'lat': 53.550707737496346,
#         'lng': 9.998298755097073,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.550707737496346,
#           'lng': 9.998298755097073}],
#         'distance': 426,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mönckebergstr. 17',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c39bc23dfb0e21eeae0b0a8-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55704c15498e200dfaff9463',
#        'name': 'Herr He',
#        'location': {'address': 'Ernst-Merck-Str. 10',
#         'crossStreet': 'Kirchenallee',
#         'lat': 53.554995210284524,
#         'lng': 10.007002110003372,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.554995210284524,
#           'lng': 10.007002110003372}],
#         'distance': 401,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ernst-Merck-Str. 10 (Kirchenallee)',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#          'name': 'Cantonese Restaurant',
#          'pluralName': 'Cantonese Restaurants',
#          'shortName': 'Cantonese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55704c15498e200dfaff9463-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05885df964a520dbc022e3',
#        'name': 'Mönckebergstraße',
#        'location': {'address': 'Mönckebergstr.',
#         'lat': 53.55127611408425,
#         'lng': 10.00178499553743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55127611408425,
#           'lng': 10.00178499553743}],
#         'distance': 323,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Mönckebergstr.',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1f9931735',
#          'name': 'Road',
#          'pluralName': 'Roads',
#          'shortName': 'Road',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05885df964a520dbc022e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bdd8706e17910002bc67d7d',
#        'name': 'Espresso House',
#        'location': {'address': 'Alstertor 1',
#         'lat': 53.551727,
#         'lng': 9.998238,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.551727,
#           'lng': 9.998238}],
#         'distance': 330,
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alstertor 1', 'Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bdd8706e17910002bc67d7d-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7e815df964a520f2ef2fe3',
#        'name': 'Bucks',
#        'location': {'address': 'Georgsplatz 1',
#         'lat': 53.55344354115736,
#         'lng': 10.002821155735148,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55344354115736,
#           'lng': 10.002821155735148}],
#         'distance': 138,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Georgsplatz 1', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7e815df964a520f2ef2fe3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf58ff20c74c9b6d9531828',
#        'name': 'Apples Restaurant',
#        'location': {'address': 'Bugenhagenstr. 8',
#         'lat': 53.55138975420903,
#         'lng': 10.003105940307595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55138975420903,
#           'lng': 10.003105940307595}],
#         'distance': 335,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Bugenhagenstr. 8',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf58ff20c74c9b6d9531828-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be58322bcef2d7fdadb03e5',
#        'name': 'Yuanye-Markt',
#        'location': {'address': 'Bugenhagenstr. 5',
#         'lat': 53.55072090773207,
#         'lng': 10.004543264014334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55072090773207,
#           'lng': 10.004543264014334}],
#         'distance': 445,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Bugenhagenstr. 5',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be58322bcef2d7fdadb03e5-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50f4466ae4b0af5bf4894982',
#        'name': 'Hotel Henri',
#        'location': {'address': 'Bugenhagenstr. 21',
#         'lat': 53.55068706116252,
#         'lng': 10.002154769677755,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55068706116252,
#           'lng': 10.002154769677755}],
#         'distance': 392,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Bugenhagenstr. 21',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50f4466ae4b0af5bf4894982-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b751a07f964a520f7fd2de3',
#        'name': 'Block House',
#        'location': {'address': 'Kirchenallee 49-51',
#         'lat': 53.55324427933013,
#         'lng': 10.008340644539686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55324427933013,
#           'lng': 10.008340644539686}],
#         'distance': 489,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Kirchenallee 49-51',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '533667906'}},
#       'referralId': 'e-0-4b751a07f964a520f7fd2de3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058861f964a52040c222e3',
#        'name': 'Deutsches Schauspielhaus',
#        'location': {'address': 'Kirchenallee 39',
#         'lat': 53.55431723947747,
#         'lng': 10.008579790592194,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55431723947747,
#           'lng': 10.008579790592194}],
#         'distance': 494,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'neighborhood': 'St. Georg',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Kirchenallee 39',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058861f964a52040c222e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b191fd8f964a52042d823e3',
#        'name': 'Thalia',
#        'location': {'address': 'Spitalerstr. 8',
#         'lat': 53.5529507,
#         'lng': 10.0031079,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.5529507,
#           'lng': 10.0031079}],
#         'distance': 188,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Spitalerstr. 8',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '473432387'}},
#       'referralId': 'e-0-4b191fd8f964a52042d823e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058859f964a520d9bf22e3',
#        'name': "CIU'",
#        'location': {'address': 'Ballindamm 14/15',
#         'lat': 53.55423278008723,
#         'lng': 9.998982581357064,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55423278008723,
#           'lng': 9.998982581357064}],
#         'distance': 140,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ballindamm 14/15',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058859f964a520d9bf22e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b1be383bed483002c64e0c1',
#        'name': 'Shiso Burger',
#        'location': {'address': 'Bugenhagenstr. 23',
#         'lat': 53.5506480910721,
#         'lng': 10.001897199200204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.5506480910721,
#           'lng': 10.001897199200204}],
#         'distance': 394,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Bugenhagenstr. 23',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b1be383bed483002c64e0c1-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505d8409e4b06ee0cbfc1821',
#        'name': 'RITUALS...',
#        'location': {'address': 'Europa Passage E2, Ballindamm 40',
#         'lat': 53.55141902,
#         'lng': 9.99686501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55141902,
#           'lng': 9.99686501}],
#         'distance': 414,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Europa Passage E2, Ballindamm 40',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '583968313'}},
#       'referralId': 'e-0-505d8409e4b06ee0cbfc1821-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba23aaef964a52051e537e3',
#        'name': 'Chen 陳',
#        'location': {'address': 'Rosenstrasse 7',
#         'lat': 53.553285,
#         'lng': 10.002196,
#         'labeledLatLngs': [{'label': 'display',
# ...
#        'location': {'address': 'Steinstr. 27',
#         'lat': 53.54988360683881,
#         'lng': 9.999582066458201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.54988360683881,
#           'lng': 9.999582066458201}],
#         'distance': 486,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Steinstr. 27', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5391572f498e87f1a9573817-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc6ee0b92b376b041c54e3a',
#        'name': 'Rossmann',
#        'location': {'address': 'Spitalerstr. 4',
#         'lat': 53.55262715844476,
#         'lng': 10.004361806828308,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55262715844476,
#           'lng': 10.004361806828308}],
#         'distance': 274,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Spitalerstr. 4',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '5745c2e4498e11e7bccabdbd',
#          'name': 'Drugstore',
#          'pluralName': 'Drugstores',
#          'shortName': 'Drugstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc6ee0b92b376b041c54e3a-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5425bc56498ef7818824f9b6',
#        'name': 'cascadas bar',
#        'location': {'address': 'Ferdinandstr. 12',
#         'lat': 53.554751,
#         'lng': 10.00034,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.554751,
#           'lng': 10.00034}],
#         'distance': 83,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ferdinandstr. 12',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5425bc56498ef7818824f9b6-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b540e9af964a52035b127e3',
#        'name': 'k presse + buch',
#        'location': {'address': 'Glockengießerwall 8-10',
#         'lat': 53.553243415765834,
#         'lng': 10.005821078852408,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.553243415765834,
#           'lng': 10.005821078852408}],
#         'distance': 328,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Glockengießerwall 8-10',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b540e9af964a52035b127e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0f76e6f964a520766223e3',
#        'name': 'Energy Clinic',
#        'location': {'address': 'An der Alster 72-79',
#         'crossStreet': 'Holzdamm',
#         'lat': 53.5577490724099,
#         'lng': 10.005229283837943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.5577490724099,
#           'lng': 10.005229283837943}],
#         'distance': 483,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['An der Alster 72-79 (Holzdamm)',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33655644'}},
#       'referralId': 'e-0-4b0f76e6f964a520766223e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ce47af964a5204b0a24e3',
#        'name': 'Jim Block',
#        'location': {'address': 'Kirchenallee 37',
#         'crossStreet': 'Heidi-Kabel-Platz',
#         'lat': 53.55469665055721,
#         'lng': 10.008124542945838,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55469665055721,
#           'lng': 10.008124542945838}],
#         'distance': 468,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Kirchenallee 37 (Heidi-Kabel-Platz)',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '529950505'}},
#       'referralId': 'e-0-4b1ce47af964a5204b0a24e3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba20fbff964a52005d937e3',
#        'name': 'Dim Sum Haus',
#        'location': {'address': 'Kirchenallee 37',
#         'lat': 53.554584,
#         'lng': 10.00845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.554584,
#           'lng': 10.00845}],
#         'distance': 488,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Kirchenallee 37',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1f5931735',
#          'name': 'Dim Sum Restaurant',
#          'pluralName': 'Dim Sum Restaurants',
#          'shortName': 'Dim Sum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba20fbff964a52005d937e3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ff5153498ec8c43385d837',
#        'name': 'Alstertor',
#        'location': {'lat': 53.55270896498078,
#         'lng': 9.99694493100598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55270896498078,
#           'lng': 9.99694493100598}],
#         'distance': 318,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ff5153498ec8c43385d837-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1c11abf964a520a00124e3',
#        'name': "Paulaner's",
#        'location': {'address': 'Kirchenallee 47',
#         'lat': 53.55346418308647,
#         'lng': 10.008375801154623,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55346418308647,
#           'lng': 10.008375801154623}],
#         'distance': 487,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Kirchenallee 47',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d10d941735',
#          'name': 'German Restaurant',
#          'pluralName': 'German Restaurants',
#          'shortName': 'German',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1c11abf964a520a00124e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ebdf27498e106ccf9b2b70',
#        'name': 'Senfbar',
#        'location': {'address': 'Hachmannplatz 16',
#         'crossStreet': 'Südsteg Hbf',
#         'lat': 53.55254187917407,
#         'lng': 10.00704127386588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55254187917407,
#           'lng': 10.00704127386588}],
#         'distance': 431,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Hachmannplatz 16 (Südsteg Hbf)',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ebdf27498e106ccf9b2b70-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bae6711f964a52092ad3be3',
#        'name': 'Gasthaus an der Alster',
#        'location': {'address': 'Ferdinandstr. 67',
#         'lat': 53.55288275512801,
#         'lng': 9.997965689874427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55288275512801,
#           'lng': 9.997965689874427}],
#         'distance': 251,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ferdinandstr. 67',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d10d941735',
#          'name': 'German Restaurant',
#          'pluralName': 'German Restaurants',
#          'shortName': 'German',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bae6711f964a52092ad3be3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572368b0cd1051829a9374f6',
#        'name': 'dean&david',
#        'location': {'address': 'Hachmannplatz 16',
#         'crossStreet': 'Südsteg',
#         'lat': 53.55246270781142,
#         'lng': 10.007254435894858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55246270781142,
#           'lng': 10.007254435894858}],
#         'distance': 448,
#         'postalCode': '20099',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Hachmannplatz 16 (Südsteg)',
#          '20099 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572368b0cd1051829a9374f6-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50144f99e4b037378d01b974',
#        'name': 'The Cube',
#        'location': {'address': 'Ferdinandstor 1',
#         'lat': 53.55589858449325,
#         'lng': 10.001642685813831,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55589858449325,
#           'lng': 10.001642685813831}],
#         'distance': 197,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Ferdinandstor 1',
#          '20095 Hamburg',
#          'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50144f99e4b037378d01b974-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b45d7d5f964a520181126e3',
#        'name': 'Balzac Coffee',
#        'location': {'address': 'Alstertor 21',
#         'lat': 53.55261517832701,
#         'lng': 9.997007086289992,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.55261517832701,
#           'lng': 9.997007086289992}],
#         'distance': 320,
#         'postalCode': '20095',
#         'cc': 'DE',
#         'city': 'Hamburg',
#         'state': 'Hamburg',
#         'country': 'Deutschland',
#         'formattedAddress': ['Alstertor 21', '20095 Hamburg', 'Deutschland']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b45d7d5f964a520181126e3-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                                            name             categories  \
# 0                                  Sakura Sushi       Sushi Restaurant
# 1  Hamburger Kunsthalle - Galerie der Gegenwart             Art Museum
# 2                               Barceló Hamburg                  Hotel
# 3                                       Quan Do  Vietnamese Restaurant
# 4                                Thalia Theater                Theater
#
#          lat        lng
# 0  53.552442  10.000058
# 1  53.555376  10.002739
# 2  53.554432  10.000625
# 3  53.553373  10.002558
# 4  53.552000   9.998338

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Let's run a code to apply the above function to each neighborhood

# %%
hamburg_venues = getNearbyVenues(names=df_hamburg['Neighborhood'],
                                   latitudes=df_hamburg['Latitude'],
                                   longitudes=df_hamburg['Longitude']
                                  )
# Out:
# Allermöhe
# Alsterdorf
# Altengamme
# Altenwerder
# Altona-Altstadt
# Altona-Nord
# Bahrenfeld
# Barmbek-Nord
# Barmbek-Süd
# Bergedorf
# Bergstedt
# Billbrook
# Billstedt
# Billwerder
# Blankenese
# Borgfelde
# Bramfeld
# Cranz
# Curslack
# Dulsberg
# Duvenstedt
# Eidelstedt
# Eilbek
# Eimsbüttel
# Eißendorf
# Eppendorf
# Farmsen-Berne
# Finkenwerder
# Francop
# Fuhlsbüttel
# Groß Borstel
# Groß Flottbek
# Gut Moor
# HafenCity
# Hamburg-Altstadt
# Hamm
# Hammerbrook
# Harburg
# Harvestehude
# Hausbruch
# Heimfeld
# Hoheluft-Ost
# Hoheluft-West
# Hohenfelde
# Horn
# Hummelsbüttel
# Iserbrook
# Jenfeld
# Kirchwerder
# Kleiner Grasbrook
# Langenbek
# Langenhorn
# Lemsahl-Mellingstedt
# Lohbrügge
# Lokstedt
# Lurup
# Marienthal
# Marmstorf
# Moorburg
# Neuallermöhe
# Neuenfelde
# Neuengamme
# Neugraben-Fischbek
# Neuland
# Neustadt
# Neuwerk
# Niendorf
# Nienstedten
# Ochsenwerder
# Ohlsdorf
# Osdorf
# Othmarschen
# Ottensen
# Poppenbüttel
# Rahlstedt
# Reitbrook
# Rissen
# Rothenburgsort
# Rotherbaum
# Rönneburg
# Sasel
# Schnelsen
# Sinstorf
# Spadenland
# St. Georg
# St. Pauli
# Steilshoop
# Steinwerder
# Stellingen
# Sternschanze
# Sülldorf
# Tatenberg
# Tonndorf
# Uhlenhorst
# Veddel
# Volksdorf
# Waltershof
# Wandsbek
# Wellingsbüttel
# Wilhelmsburg
# Wilstorf
# Winterhude
# Wohldorf-Ohlstedt

# %%
hamburg_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Allermöhe              53.450581               10.144101
# 1    Allermöhe              53.450581               10.144101
# 2    Allermöhe              53.450581               10.144101
# 3    Allermöhe              53.450581               10.144101
# 4   Alsterdorf              53.611496               10.012196
#
#                    Venue  Venue Latitude  Venue Longitude   Venue Category
# 0                   SC4M       53.449580        10.135803     Soccer Field
# 1  Sporthalle Fünfhausen       53.449196        10.135578       Theme Park
# 2      Braatz Informatik       53.445650        10.134290      IT Services
# 3           Paddel Meier       53.458001        10.139787  Harbor / Marina
# 4    Eiskaffee Eis Perle       53.608354        10.009394   Ice Cream Shop

# %% [markdown]
# Let's check how many venues were returned for each neighborhood

# %%
hamburg_venues.groupby('Neighborhood').count()
# Out:
#                       Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Allermöhe                                 4                       4      4
# Alsterdorf                               29                      29     29
# Altenwerder                               2                       2      2
# Altona-Altstadt                         100                     100    100
# Altona-Nord                             100                     100    100
# Bahrenfeld                               15                      15     15
# Barmbek-Nord                             65                      65     65
# Barmbek-Süd                             100                     100    100
# Bergedorf                                 6                       6      6
# Bergstedt                                 6                       6      6
# Billbrook                                12                      12     12
# Billstedt                                 7                       7      7
# Billwerder                               10                      10     10
# Blankenese                               30                      30     30
# Borgfelde                                46                      46     46
# Bramfeld                                  6                       6      6
# Cranz                                     2                       2      2
# Dulsberg                                 37                      37     37
# Duvenstedt                                5                       5      5
# Eidelstedt                               17                      17     17
# Eilbek                                   68                      68     68
# Eimsbüttel                               83                      83     83
# Eißendorf                                47                      47     47
# Eppendorf                                28                      28     28
# Farmsen-Berne                            12                      12     12
# Finkenwerder                              2                       2      2
# Francop                                   2                       2      2
# Fuhlsbüttel                              31                      31     31
# Groß Borstel                             31                      31     31
# Groß Flottbek                            15                      15     15
# Gut Moor                                 39                      39     39
# HafenCity                                37                      37     37
# Hamburg-Altstadt                        100                     100    100
# Hamm                                     46                      46     46
# Hammerbrook                              91                      91     91
# Harburg                                  47                      47     47
# Harvestehude                             80                      80     80
# Heimfeld                                 39                      39     39
# Hoheluft-Ost                             78                      78     78
# Hoheluft-West                            96                      96     96
# Hohenfelde                               91                      91     91
# Horn                                     21                      21     21
# Hummelsbüttel                             5                       5      5
# Iserbrook                                 5                       5      5
# Jenfeld                                  13                      13     13
# Kirchwerder                               4                       4      4
# Kleiner Grasbrook                        37                      37     37
# Langenbek                                39                      39     39
# Langenhorn                                6                       6      6
# Lemsahl-Mellingstedt                      5                       5      5
# Lohbrügge                                10                      10     10
# Lokstedt                                 28                      28     28
# Lurup                                    15                      15     15
# Marienthal                               13                      13     13
# Marmstorf                                 5                       5      5
# Moorburg                                 39                      39     39
# Neuallermöhe                              6                       6      6
# Neuenfelde                                2                       2      2
# Neugraben-Fischbek                        5                       5      5
# Neuland                                  39                      39     39
# Neustadt                                100                     100    100
# Niendorf                                 11                      11     11
# Nienstedten                              14                      14     14
# Ochsenwerder                              4                       4      4
# Ohlsdorf                                 29                      29     29
# Osdorf                                   12                      12     12
# Othmarschen                              27                      27     27
# Ottensen                                100                     100    100
# Poppenbüttel                              5                       5      5
# Rahlstedt                                 1                       1      1
# Reitbrook                                 4                       4      4
# Rissen                                   10                      10     10
# Rothenburgsort                           12                      12     12
# Rotherbaum                               94                      94     94
# Rönneburg                                39                      39     39
# Sasel                                    12                      12     12
# Schnelsen                                17                      17     17
# Sinstorf                                 39                      39     39
# Spadenland                                4                       4      4
# St. Georg                                91                      91     91
# St. Pauli                               100                     100    100
# Steilshoop                               13                      13     13
# Steinwerder                              37                      37     37
# Stellingen                               25                      25     25
# Sternschanze                            100                     100    100
# Sülldorf                                  5                       5      5
# Tatenberg                                 4                       4      4
# Tonndorf                                 21                      21     21
# Uhlenhorst                               53                      53     53
# Veddel                                   12                      12     12
# Volksdorf                                24                      24     24
# Waltershof                                2                       2      2
# Wandsbek                                 76                      76     76
# Wellingsbüttel                           12                      12     12
# Wilhelmsburg                             37                      37     37
# Wilstorf                                  5                       5      5
# Winterhude                               48                      48     48
# Wohldorf-Ohlstedt                         5                       5      5
#
#                       Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Allermöhe                          4                4               4
# Alsterdorf                        29               29              29
# Altenwerder                        2                2               2
# Altona-Altstadt                  100              100             100
# Altona-Nord                      100              100             100
# Bahrenfeld                        15               15              15
# Barmbek-Nord                      65               65              65
# Barmbek-Süd                      100              100             100
# Bergedorf                          6                6               6
# Bergstedt                          6                6               6
# Billbrook                         12               12              12
# Billstedt                          7                7               7
# Billwerder                        10               10              10
# Blankenese                        30               30              30
# Borgfelde                         46               46              46
# Bramfeld                           6                6               6
# Cranz                              2                2               2
# Dulsberg                          37               37              37
# Duvenstedt                         5                5               5
# Eidelstedt                        17               17              17
# Eilbek                            68               68              68
# Eimsbüttel                        83               83              83
# Eißendorf                         47               47              47
# Eppendorf                         28               28              28
# Farmsen-Berne                     12               12              12
# Finkenwerder                       2                2               2
# Francop                            2                2               2
# Fuhlsbüttel                       31               31              31
# Groß Borstel                      31               31              31
# Groß Flottbek                     15               15              15
# Gut Moor                          39               39              39
# HafenCity                         37               37              37
# Hamburg-Altstadt                 100              100             100
# Hamm                              46               46              46
# Hammerbrook                       91               91              91
# Harburg                           47               47              47
# Harvestehude                      80               80              80
# Heimfeld                          39               39              39
# Hoheluft-Ost                      78               78              78
# Hoheluft-West                     96               96              96
# Hohenfelde                        91               91              91
# Horn                              21               21              21
# Hummelsbüttel                      5                5               5
# Iserbrook                          5                5               5
# Jenfeld                           13               13              13
# Kirchwerder                        4                4               4
# Kleiner Grasbrook                 37               37              37
# Langenbek                         39               39              39
# Langenhorn                         6                6               6
# Lemsahl-Mellingstedt               5                5               5
# Lohbrügge                         10               10              10
# Lokstedt                          28               28              28
# Lurup                             15               15              15
# Marienthal                        13               13              13
# Marmstorf                          5                5               5
# Moorburg                          39               39              39
# Neuallermöhe                       6                6               6
# Neuenfelde                         2                2               2
# Neugraben-Fischbek                 5                5               5
# Neuland                           39               39              39
# Neustadt                         100              100             100
# Niendorf                          11               11              11
# Nienstedten                       14               14              14
# Ochsenwerder                       4                4               4
# Ohlsdorf                          29               29              29
# Osdorf                            12               12              12
# Othmarschen                       27               27              27
# Ottensen                         100              100             100
# Poppenbüttel                       5                5               5
# Rahlstedt                          1                1               1
# Reitbrook                          4                4               4
# Rissen                            10               10              10
# Rothenburgsort                    12               12              12
# Rotherbaum                        94               94              94
# Rönneburg                         39               39              39
# Sasel                             12               12              12
# Schnelsen                         17               17              17
# Sinstorf                          39               39              39
# Spadenland                         4                4               4
# St. Georg                         91               91              91
# St. Pauli                        100              100             100
# Steilshoop                        13               13              13
# Steinwerder                       37               37              37
# Stellingen                        25               25              25
# Sternschanze                     100              100             100
# Sülldorf                           5                5               5
# Tatenberg                          4                4               4
# Tonndorf                          21               21              21
# Uhlenhorst                        53               53              53
# Veddel                            12               12              12
# Volksdorf                         24               24              24
# Waltershof                         2                2               2
# Wandsbek                          76               76              76
# Wellingsbüttel                    12               12              12
# Wilhelmsburg                      37               37              37
# Wilstorf                           5                5               5
# Winterhude                        48               48              48
# Wohldorf-Ohlstedt                  5                5               5

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(hamburg_venues['Venue Category'].unique())))
# Out:
# There are 279 uniques categories.

# %% [markdown]
# # Explore the venues that contais Parks or Sport in its category

# %%
hamburg_venues[hamburg_venues['Venue Category'].str.contains("Park|Sport")]
# Out:
#               Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1                Allermöhe              53.450581               10.144101
# 22              Alsterdorf              53.611496               10.012196
# 37         Altona-Altstadt              53.553175                9.947594
# 44         Altona-Altstadt              53.553175                9.947594
# 67         Altona-Altstadt              53.553175                9.947594
# 191            Altona-Nord              53.557255                9.932502
# 308           Barmbek-Nord              53.591714               10.049692
# 334            Barmbek-Süd              53.574655               10.015176
# 343            Barmbek-Süd              53.574655               10.015176
# 367            Barmbek-Süd              53.574655               10.015176
# 428              Billbrook              53.528866               10.046461
# 480             Blankenese              53.565260                9.799340
# 491              Borgfelde              53.562062               10.049668
# 503              Borgfelde              53.562062               10.049668
# 581             Duvenstedt              53.706996               10.124170
# 606                 Eilbek              53.570657               10.047103
# 616                 Eilbek              53.570657               10.047103
# 645                 Eilbek              53.570657               10.047103
# 653                 Eilbek              53.570657               10.047103
# 662                 Eilbek              53.570657               10.047103
# 706             Eimsbüttel              53.579107                9.942673
# 722             Eimsbüttel              53.579107                9.942673
# 740             Eimsbüttel              53.579107                9.942673
# 745             Eimsbüttel              53.579107                9.942673
# 819              Eppendorf              53.598736                9.955756
# 1099                  Hamm              53.562062               10.049668
# 1111                  Hamm              53.562062               10.049668
# 1294          Harvestehude              53.581092                9.992131
# 1312          Harvestehude              53.581092                9.992131
# 1329          Harvestehude              53.581092                9.992131
# 1401          Hoheluft-Ost              53.595006                9.977862
# 1402          Hoheluft-Ost              53.595006                9.977862
# 1415          Hoheluft-Ost              53.595006                9.977862
# 1424          Hoheluft-Ost              53.595006                9.977862
# 1469          Hoheluft-Ost              53.595006                9.977862
# 1489         Hoheluft-West              53.582910                9.966791
# 1539         Hoheluft-West              53.582910                9.966791
# 1569         Hoheluft-West              53.582910                9.966791
# 1579            Hohenfelde              53.565123               10.024729
# 1595            Hohenfelde              53.565123               10.024729
# 1620            Hohenfelde              53.565123               10.024729
# 1657            Hohenfelde              53.565123               10.024729
# 1672                  Horn              53.550699               10.082665
# 1675                  Horn              53.550699               10.082665
# 1676                  Horn              53.550699               10.082665
# 1686         Hummelsbüttel              53.667414               10.070814
# 1707           Kirchwerder              53.450581               10.144101
# 1791            Langenhorn              53.670652               10.034496
# 1796  Lemsahl-Mellingstedt              53.706996               10.124170
# 1829              Lokstedt              53.598736                9.955756
# 1915    Neugraben-Fischbek              53.463487                9.857171
# 1963              Neustadt              53.558257                9.978956
# 2003              Neustadt              53.558257                9.978956
# 2073           Nienstedten              53.561456                9.850548
# 2078           Nienstedten              53.561456                9.850548
# 2081           Nienstedten              53.561456                9.850548
# 2082           Nienstedten              53.561456                9.850548
# 2085          Ochsenwerder              53.450581               10.144101
# 2106              Ohlsdorf              53.611496               10.012196
# 2128                Osdorf              53.587857                9.854926
# 2135           Othmarschen              53.552819                9.887015
# 2152           Othmarschen              53.552819                9.887015
# 2154           Othmarschen              53.552819                9.887015
# 2155           Othmarschen              53.552819                9.887015
# 2212              Ottensen              53.557255                9.932502
# 2259          Poppenbüttel              53.667414               10.070814
# 2263             Reitbrook              53.450581               10.144101
# 2271                Rissen              53.590292                9.760451
# 2277        Rothenburgsort              53.528866               10.046461
# 2327            Rotherbaum              53.570563                9.978171
# 2341            Rotherbaum              53.570563                9.978171
# 2444             Schnelsen              53.641559                9.911204
# 2490            Spadenland              53.450581               10.144101
# 2501             St. Georg              53.565123               10.024729
# 2517             St. Georg              53.565123               10.024729
# 2542             St. Georg              53.565123               10.024729
# 2579             St. Georg              53.565123               10.024729
# 2648             St. Pauli              53.553306                9.965141
# 2756            Stellingen              53.602410                9.928548
# 2774          Sternschanze              53.565085                9.966303
# 2865             Tatenberg              53.450581               10.144101
# 2900            Uhlenhorst              53.578604               10.043227
# 2938            Uhlenhorst              53.578604               10.043227
# 2943                Veddel              53.528866               10.046461
# 2980              Wandsbek              53.578344               10.076306
# 3040              Wandsbek              53.578344               10.076306
# 3041              Wandsbek              53.578344               10.076306
# 3053              Wandsbek              53.578344               10.076306
# 3110            Winterhude              53.594214               10.022195
# 3143            Winterhude              53.594214               10.022195
# 3144            Winterhude              53.594214               10.022195
# 3157            Winterhude              53.594214               10.022195
# 3162     Wohldorf-Ohlstedt              53.706996               10.124170
#
#                                      Venue  Venue Latitude  Venue Longitude  \
# 1                    Sporthalle Fünfhausen       53.449196        10.135578
# 22                              Alsterufer       53.613294        10.002261
# 37                                Festland       53.554664         9.951444
# 44     Wohlers Park (Friedhof Norderreihe)       53.558589         9.953012
# 67              Altonaer Turnverband (ATV)       53.548921         9.949059
# 191                      Kemal-Altun-Platz       53.552490         9.925879
# 308                            Wendebecken       53.598710        10.054479
# 334                             Alsterpark       53.568867        10.013555
# 343                          Alstervorland       53.573779        10.001142
# 367                     Parkbänke Bellevue       53.577069        10.004595
# 428                    Elbpark Entenwerder       53.531878        10.033994
# 480                            Goßler Park       53.564207         9.808369
# 491                            Hammer Park       53.558971        10.058756
# 503                             Jacobipark       53.566862        10.053998
# 581                     Park zur Besinnung       53.706944        10.111442
# 606                  Friedrichsberger Park       53.575210        10.053906
# 616                             Jacobipark       53.566862        10.053998
# 645                              Decathlon       53.570891        10.061024
# 653                    Eilbeker Bürgerpark       53.564028        10.049413
# 662                            Häschenpark       53.579116        10.050241
# 706                               Unnapark       53.575788         9.950022
# 722                     Park Am Wasserturm       53.586735         9.942153
# 740                     Compass Segelsport       53.573020         9.940170
# 745                   Grün-Weiß Eimsbüttel       53.584274         9.952259
# 819                            Amsinckpark       53.601400         9.942927
# 1099                           Hammer Park       53.558971        10.058756
# 1111                            Jacobipark       53.566862        10.053998
# 1294                        Innocentiapark       53.578126         9.982893
# 1312                      Kellinghusenpark       53.588550         9.988192
# 1329                    Parkbänke Bellevue       53.577069        10.004595
# 1401                      Eppendorfer Park       53.589614         9.979384
# 1402                            Hayns Park       53.595472         9.989512
# 1415                       Winterhuder Kai       53.594390         9.992516
# 1424                      Kellinghusenpark       53.588550         9.988192
# 1469                            Meenkwiese       53.597779         9.990669
# 1489          Eimsbüttler Park „Am Weiher“       53.578016         9.960040
# 1539                              Laufwerk       53.580515         9.973869
# 1569                  Grün-Weiß Eimsbüttel       53.584274         9.952259
# 1579                     Alster-Grillwiese       53.564261        10.015973
# 1595                            Alsterpark       53.568867        10.013555
# 1620                         Lohmühlenpark       53.558991        10.016468
# 1657  Aspria Hamburg Uhlenhorst Schwimmbad       53.570797        10.016966
# 1672                           Horner Park       53.547106        10.083072
# 1675                           Blohms Park       53.551883        10.075454
# 1676                     Lisa-Niebank-Park       53.551261        10.090942
# 1686               Jump House Poppenbüttel       53.663703        10.076603
# 1707                 Sporthalle Fünfhausen       53.449196        10.135578
# 1791                      Kiwittsmoor Park       53.670483        10.020829
# 1796                    Park zur Besinnung       53.706944        10.111442
# 1829                           Amsinckpark       53.601400         9.942927
# 1915                      Fischbeker Heide       53.459002         9.867761
# 1963                     Planten un Blomen       53.560552         9.983912
# 2003                           Wallanlagen       53.553235         9.974599
# 2073                   Hamburger Polo Club       53.560413         9.855500
# 2078         Sportplatz Hemmingstedter Weg       53.567873         9.855955
# 2081    Deutsches Spring- und Dressurderby       53.556234         9.862054
# 2082                            Westerpark       53.554751         9.859972
# 2085                 Sporthalle Fünfhausen       53.449196        10.135578
# 2106                            Alsterufer       53.613294        10.002261
# 2128                             Born Park       53.596101         9.852513
# 2135                     Schröders Elbpark       53.545790         9.893081
# 2152                      Ringelnatztreppe       53.545135         9.886030
# 2154                         Reemtsma-Park       53.550915         9.874091
# 2155                        Hindenburgpark       53.546327         9.877825
# 2212                     Kemal-Altun-Platz       53.552490         9.925879
# 2259               Jump House Poppenbüttel       53.663703        10.076603
# 2263                 Sporthalle Fünfhausen       53.449196        10.135578
# 2271                           Schöns Park       53.585855         9.752702
# 2277                   Elbpark Entenwerder       53.531878        10.033994
# 2327                     Sternschanzenpark       53.565955         9.970007
# 2341                        Innocentiapark       53.578126         9.982893
# 2444                        Wassermannpark       53.647720         9.914314
# 2490                 Sporthalle Fünfhausen       53.449196        10.135578
# 2501                     Alster-Grillwiese       53.564261        10.015973
# 2517                            Alsterpark       53.568867        10.013555
# 2542                         Lohmühlenpark       53.558991        10.016468
# 2579  Aspria Hamburg Uhlenhorst Schwimmbad       53.570797        10.016966
# 2648                           Wallanlagen       53.553235         9.974599
# 2756                           Amsinckpark       53.601400         9.942927
# 2774                     Sternschanzenpark       53.565955         9.970007
# 2865                 Sporthalle Fünfhausen       53.449196        10.135578
# 2900                 Friedrichsberger Park       53.575210        10.053906
# 2938            Original Bootcamp - Eilbek       53.573625        10.055225
# 2943                   Elbpark Entenwerder       53.531878        10.033994
# 2980                           Eichtalpark       53.578351        10.082425
# 3040             Sporthalle Alter Teichweg       53.584672        10.071522
# 3041             Olympiastützpunkt Hamburg       53.584677        10.071513
# 3053                      Dulsberg Grünzug       53.585053        10.067477
# 3110                             Stadtpark       53.596325        10.019059
# 3143                      Hamburg Pioneers       53.600226        10.018088
# 3144                    Alter Güterbahnhof       53.593286        10.034552
# 3157               FitnessStudio City Nord       53.602770        10.024921
# 3162                    Park zur Besinnung       53.706944        10.111442
#
#            Venue Category
# 1              Theme Park
# 22                   Park
# 37             Water Park
# 44                   Park
# 67            Sports Club
# 191                  Park
# 308                  Park
# 334                  Park
# 343                  Park
# 367                  Park
# 428                  Park
# 480                  Park
# 491                  Park
# 503                  Park
# 581                  Park
# 606                  Park
# 616                  Park
# 645   Sporting Goods Shop
# 653                  Park
# 662                  Park
# 706                  Park
# 722                  Park
# 740   Sporting Goods Shop
# 745           Sports Club
# 819                  Park
# 1099                 Park
# 1111                 Park
# 1294                 Park
# 1312                 Park
# 1329                 Park
# 1401                 Park
# 1402                 Park
# 1415                 Park
# 1424                 Park
# 1469                 Park
# 1489                 Park
# 1539  Sporting Goods Shop
# 1569          Sports Club
# 1579                 Park
# 1595                 Park
# 1620                 Park
# 1657   Athletics & Sports
# 1672                 Park
# 1675                 Park
# 1676                 Park
# 1686   Athletics & Sports
# 1707           Theme Park
# 1791                 Park
# 1796                 Park
# 1829                 Park
# 1915                 Park
# 1963                 Park
# 2003                 Park
# 2073          Sports Club
# 2078   Athletics & Sports
# 2081   Athletics & Sports
# 2082                 Park
# 2085           Theme Park
# 2106                 Park
# 2128                 Park
# 2135                 Park
# 2152                 Park
# 2154                 Park
# 2155                 Park
# 2212                 Park
# 2259   Athletics & Sports
# 2263           Theme Park
# 2271                 Park
# 2277                 Park
# 2327                 Park
# 2341                 Park
# 2444                 Park
# 2490           Theme Park
# 2501                 Park
# 2517                 Park
# 2542                 Park
# 2579   Athletics & Sports
# 2648                 Park
# 2756                 Park
# 2774                 Park
# 2865           Theme Park
# 2900                 Park
# 2938   Athletics & Sports
# 2943                 Park
# 2980                 Park
# 3040   Athletics & Sports
# 3041   Athletics & Sports
# 3053                 Park
# 3110                 Park
# 3143          Sports Club
# 3144           Skate Park
# 3157   Athletics & Sports
# 3162                 Park

# %% [markdown]
# Let's assign this data set to a new dataframe

# %%
df_h=hamburg_venues[hamburg_venues['Venue Category'].str.contains("Park|Sport")]
df_h.shape
# Out:
# (93, 7)

# %% [markdown]
# there were found 93 locations that meet the requariment

# %%
# create map of Hamburg using latitude and longitude values
map_hamburg1 = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(hamburg_venues1['Venue Latitude'], hamburg_venues1['Venue Longitude'], hamburg_venues1['Venue Category']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue' ,
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_hamburg1)  
    
map_hamburg1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7b08fe43db6a461d873d764b392704bf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7b08fe43db6a461d873d764b392704bf%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7b08fe43db6a461d873d764b392704bf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7b08fe43db6a461d873d764b392704bf%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.550341%2C%2010.000654%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# From this map we can can conclude that the North part of Hamburg contains the most Park and Sport Venues, whereas the South part has almost no such locations. In reality it is not so. South Hamburg is full of green and sport areas as well. It seems that Foresquare database contains incomplete information about Hamburg and schould be extended with data for this region to provide us with sufitiant information for further analysis
